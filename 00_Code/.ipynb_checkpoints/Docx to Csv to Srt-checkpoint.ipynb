# %%
import os
import docx
import re
import csv
from collections import defaultdict

# %% [markdown]
# <h3> Transcripts to CSVs </h3>

# %%
def clean_subtitle(text):
    # Remove asterisks and text between brackets
    text = re.sub(r'\*|\[.*?\]', '', text)
    text = re.sub(r'[\u2012\u2013\u2014\u2015]', '-', text)
    text = text.replace(";",":")
    return text.strip()

def convert_language_to_csv(language, input_file, subtitles):
    doc = docx.Document(input_file)
    subtitle_block = ""
    current_time_range = None
    current_highlight_color = None
    for paragraph in doc.paragraphs:
        text = paragraph.text.strip()
        text = clean_subtitle(text)  # Clean the subtitle text
        # Check if the paragraph contains a time range
        time_range_match = re.match(r'^(\d+[:;]\d+(?::\d+){0,2}\s*-\s*\d+[:;]\d+(?::\d+){0,2})\s*\**', text)
        if time_range_match:
            time_range = time_range_match.group(1)
            # If there's a previous subtitle block, add it to the dictionary
            if subtitle_block and current_time_range:
                subtitles[current_time_range][language] = {
                    "text": subtitle_block,
                    "highlight_color": current_highlight_color,
                    "comments": ""  # Initialize an empty "Comments" column
                }
            subtitle_block = ""
            current_time_range = time_range
            current_highlight_color = None  # Reset the highlight color for a new time range
        else:
            # Extract the highlight color for each run in the paragraph
            for run in paragraph.runs:
                if run.font.highlight_color is not None:
                    current_highlight_color = run.font.highlight_color
            subtitle_block += text + "\n"

    # Add the last subtitle block to the dictionary
    if subtitle_block and current_time_range:
        subtitles[current_time_range][language] = {
            "text": subtitle_block,
            "highlight_color": current_highlight_color,
            "comments": ""  # Initialize an empty "Comments" column
        }

def interview_to_csv(input_files, output_csv_file):
    # Initialize a dictionary to store subtitles for all languages
    all_subtitles = defaultdict(lambda: defaultdict(str))

    # Iterate through each language and convert to CSV
    for language, input_file in input_files.items():
        convert_language_to_csv(language, input_file, all_subtitles)

    # Write the combined subtitles to the CSV file
    with open(output_csv_file, 'w', newline='', encoding='utf-8') as f:
        csv_writer = csv.writer(f)
        # Write the header row
        header = ["Start Time", "End Time"] + list(input_files.keys()) + ["Highlight", "Comments"]
        csv_writer.writerow(header)
        # Write the data rows with all languages stacked
        for time_range, language_subtitles in all_subtitles.items():
            try:
                start_time, end_time = map(str.strip, time_range.split("-"))
                highlight_color = language_subtitles[list(input_files.keys())[0]]["highlight_color"]
                row = [start_time, end_time] + [clean_subtitle(language_subtitles.get(lang, {"text": ""})["text"]) for lang in input_files.keys()] + [highlight_color, ""]
                csv_writer.writerow(row)
            except:
                print("broken: ", language_subtitles)

    print(f"Conversion completed. Data saved to {output_csv_file}")

# # Test
# input_files = {
#     "English": "../02_Transcripts/Wayuu/Transcripts (EN)/dunas (EN).docx",
#     "Spanish": "../02_Transcripts/Wayuu/Transcripts (ES)/dunas (ES).docx"
# }
# output_csv_file = "../04_Interview CSV/dunas.csv"

# # Convert all languages to CSV using the pipeline function
# interview_to_csv(input_files, output_csv_file)

# %%
#run the processing pipeline overall interviews

transcripts_dir = "../02_Transcripts/Wayuu/"

def get_languages_and_interviews(transcripts_dir):
    interviews_dict = {}  # Dictionary to store interviews and their languages and file paths

    for language_folder in os.listdir(transcripts_dir):
        language_dir_path = os.path.join(transcripts_dir, language_folder)
        
        # Check if it's a valid language folder (e.g., "Transcripts (EN)")
        if os.path.isdir(language_dir_path) and language_folder.startswith("Transcripts ("):
            language = language_folder.split(" (")[1].split(")")[0]
            
            for interview_file in os.listdir(language_dir_path):
                if interview_file.endswith(".docx") and not os.path.basename(interview_file).startswith("~$"):
                    interview_name, ext = os.path.splitext(interview_file)
                    interview_code = interview_name.split("(")[0].strip()  # Extract the interview code (e.g., "dunas")
                    interview_path = os.path.join(language_dir_path, interview_file)
                    
                    # Create or update the entry for this interview code
                    if interview_code not in interviews_dict:
                        interviews_dict[interview_code] = {}
                    
                    # Append language and file path to the input_files dictionary
                    interviews_dict[interview_code][language] = interview_path

    return interviews_dict    

def process_all_interviews(transcripts_dir, output_csv_dir):
    # Get the combined dictionary of languages and interviews
    interviews_dict = get_languages_and_interviews(transcripts_dir)

    #print(interviews_dict)
    
    for interview_code in interviews_dict.keys():
        print(interview_code)
        # Process the interview using the input_files and interview_code
        output_csv_file = os.path.join(output_csv_dir, f"{interview_code}.csv")
        interview_to_csv(interviews_dict[interview_code], output_csv_file)
        

# Output directory for CSV files
output_csv_dir = "../04_Interview CSV/"

# Process all interviews in the transcripts directory
process_all_interviews(transcripts_dir, output_csv_dir)
# Out:
# weildler inside
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'externa.\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'marítimo.\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'transformativos\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'El\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# Conversion completed. Data saved to ../04_Interview CSV/weildler inside.csv
# Neko urbana
# Conversion completed. Data saved to ../04_Interview CSV/Neko urbana.csv
# Abuelo pescador
# Conversion completed. Data saved to ../04_Interview CSV/Abuelo pescador.csv
# abuela pescadora
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Si, como un intercambio de regalos\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# Conversion completed. Data saved to ../04_Interview CSV/abuela pescadora.csv
# tejedora abuela
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Sí, es verdad, no son producto de la lluvia\n\n', 'highlight_color': 7, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'que provienen de las plantas y otras de las montañas\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# Conversion completed. Data saved to ../04_Interview CSV/tejedora abuela.csv
# Joaquin
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Wayakana shipi´jala tüü mmakat.\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Y por eso existen nuestros ancestros\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'pone trabajadores.\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'los arijuna nosotros decimos arijuna porque no es wayuu. No,\nya se me murió, no\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Este es un toque aquí del wayuu enamorado y es así\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Este se llama un ontoroyoi, perdón\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'como ven es de metal muy diferente a la planta.\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'y comienzan a hacer de esta manera así\ny cuando llueve también comienzan aletear.\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'y la naturaleza del tema.\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Pues hay una armonía en la naturaleza ya, y para mi\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'parece que la música está\nintentando de llegar a esa armonía más, de\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'concentrar las cosas de estar como más conectado.\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'mantenemos la música a través de la espiritualidad,\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'y allá es diferente\nporque tengo conexión con la naturaleza,\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'y el cuerpo,\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'es metálico,fue traído por los colonizadores\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': '¿Qué tan importante considera la música?\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'con un maasi o un sawawa nada más, pero\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Todo tiene un\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'legado y tiene una connotación espiritual,\nporque eso es lo que permiten las mujeres\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'porque con ella nosotros también\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Esos Peltres no son de nosotros, eso vino desde la conquista\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Te canta una ranchera\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Si claro.\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'de su historia, de ella, lo\nque vive de tristeza o de lamento.\n\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Yo siempre he dicho un tema,\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'tenemos conocimiento de usarlo en el documental\ny la música también.\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'o lo que nos tocaste\npara ser parte de este proyecto que estamos haciendo?\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'una entrevista no los pasa que nos sirve también para mantenernos.\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Población, Patrimonio, con nosotros\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'El del fondo mixto del departamento\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Entonces eso era nada más para nosotros.\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'de pronto llegan, personas como ustedes que nos\nvisitan y nos traen\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# Conversion completed. Data saved to ../04_Interview CSV/Joaquin.csv
# Healing Woman
# Conversion completed. Data saved to ../04_Interview CSV/Healing Woman.csv
# pinta abuela
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'En cambio, los hijos de los hombres ya son de\notra familia (la de la madre). Así es\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# Conversion completed. Data saved to ../04_Interview CSV/pinta abuela.csv
# salinero oscar
# Conversion completed. Data saved to ../04_Interview CSV/salinero oscar.csv
# Magalys Hammock
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Para emprender una nueva experiencia durante el\ntiempo que estuve\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'por eso, la mujer es la base de nuestra organización\nsocial a partir de la madre\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'En cambio, el padre no, porque no influye tanto\npor eso se puede ir normal\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Que ¿en dónde nos encontramos ahora?\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Y ¿Cuál es la diferencia de aquí con las otras zonas?\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Lo primero o lo principal de todo es lo que les\ndije hace rato\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# Conversion completed. Data saved to ../04_Interview CSV/Magalys Hammock.csv
# neko father
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Cuando esta agua se acabe vamos a sufrir mucho\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# Conversion completed. Data saved to ../04_Interview CSV/neko father.csv
# Neko piedra
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Y la de Magalys\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'que Wuimpumiun, la alta Guajira\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'el ave era una persona y escucharon las diferentes aves y estaba\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# Conversion completed. Data saved to ../04_Interview CSV/Neko piedra.csv
# palabrero luis
# Conversion completed. Data saved to ../04_Interview CSV/palabrero luis.csv
# weildler outside
# Conversion completed. Data saved to ../04_Interview CSV/weildler outside.csv
# Ana weaving
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'de tejidos, mochilas, varias clases de mochila\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'bueno, ya que aquí en la ranchería\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'que mi trabajo es tiene que ver es aquí.\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'ya se hizo una señorita ahí mismo y la encerraron\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'hay muchos tipos de plantas\nque a veces uno\n\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'pero las niñas también, a veces se entrenan que\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'quieren aprender y a los cinco años\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'es la que como te digo,\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'es tierra, xxx: tierra\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Y eso.\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'y por eso es que todo es muy importante.\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'pero mi nombre completo es Ana Luisa,\nmi clan es el xxx\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# Conversion completed. Data saved to ../04_Interview CSV/Ana weaving.csv
# weildler pre
# Conversion completed. Data saved to ../04_Interview CSV/weildler pre.csv
# Magalys electrico
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Solar.\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'amperaje.\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'resistencia.\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# Conversion completed. Data saved to ../04_Interview CSV/Magalys electrico.csv
# Neko weaving
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'como que\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# Conversion completed. Data saved to ../04_Interview CSV/Neko weaving.csv
# romelia
# Conversion completed. Data saved to ../04_Interview CSV/romelia.csv
# Wolunka
# broken:  defaultdict(<class 'str'>, {'ES': {'text': 'Decidieron entonces que debían tumbarle los dientes,\nlos de la vagina\n\n', 'highlight_color': None, 'comments': ''}, 'EN': ''})
# Conversion completed. Data saved to ../04_Interview CSV/Wolunka.csv
# Eliana
# Conversion completed. Data saved to ../04_Interview CSV/Eliana.csv
# salinero young
# Conversion completed. Data saved to ../04_Interview CSV/salinero young.csv
# dunas
# Conversion completed. Data saved to ../04_Interview CSV/dunas.csv
# Neko Urbana
# Conversion completed. Data saved to ../04_Interview CSV/Neko Urbana.csv
# SALINERO YOUNG
# Conversion completed. Data saved to ../04_Interview CSV/SALINERO YOUNG.csv

# %% [markdown]
# <h3>CSVs to SRTs</h3>
