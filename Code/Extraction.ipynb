# %%
import os
import pandas as pd
import re
from datetime import datetime, timedelta

def clean_text(text):
    # Remove special characters from the text
    cleaned_text = re.sub(r"[^\w\s]", "", text)
    return cleaned_text

def match_line(line, df):
    cleaned_line = clean_text(line.lower())  
    matched_rows = []
    for _, row in df.iterrows():
        transcription = clean_text(str(row['TRANSCRIPTION (SESOTHO)']).lower())
        translation = clean_text(str(row['TRANSLATION (ENGLISH)']).lower())
        if cleaned_line in transcription or cleaned_line in translation:
            matched_rows.append(row) 
    matched_rows_df = pd.concat(matched_rows, axis=1).transpose() if matched_rows else pd.DataFrame()
    return matched_rows_df

def get_word_indices(full_string, substring):
    full_list = full_string.split()
    sub_list = substring.split()
    length = len(sub_list)
    
    for i in range(len(full_list)):
        if full_list[i:i+length] == sub_list:
            return i, i+length
    return None, None

folder_path = "../Interview XLSX/"
file_extension = ".xlsx"

combined_df = pd.DataFrame()

for filename in os.listdir(folder_path):
    if filename.endswith(file_extension):
        file_path = os.path.join(folder_path, filename)
        df = pd.read_excel(file_path)
        df['filepath'] = file_path
        combined_df = pd.concat([combined_df, df], ignore_index=True)

matched_rows = []

with open('../Script/test script.txt', 'r', encoding='utf-8') as file:
    lines = file.readlines()

narrator = None
language = None
for line in lines:
    line = line.strip().lower()
    if line.startswith('***'):
        narrator = line[3:].strip().lower()
        language = 'SESOTHO'
    elif line.startswith('###'):
        narrator = line[3:].strip().lower()
        language = 'ENGLISH'
    elif line and narrator and language:
        matched_rows_df = match_line(line, combined_df)
        cleaned_line = clean_text(line)
        if not matched_rows_df.empty:
            for _, row in matched_rows_df.iterrows():
                time_range = row['TIME'].split(" - ")
                start_time = datetime.strptime(time_range[0], '%H:%M:%S')
                end_time = datetime.strptime(time_range[1], '%H:%M:%S')
                total_duration = (end_time - start_time).total_seconds()

                transcription = clean_text(str(row['TRANSCRIPTION (SESOTHO)']).lower())
                translation = clean_text(str(row['TRANSLATION (ENGLISH)']).lower())
                original_text = transcription if cleaned_line in transcription else translation
                if cleaned_line == original_text:
                    new_row = {
                        'Text': line,
                        'Narrator': narrator,
                        'Language': language,
                        'Timecode Range': row['TIME'],
                        'FilePath': row['filepath']
                    }
                else:
                    start_index, end_index = get_word_indices(original_text, cleaned_line)
                    total_words = len(original_text.split())
                    start_time = start_time + timedelta(seconds=total_duration*start_index/total_words)
                    end_time = start_time + timedelta(seconds=total_duration*(end_index-start_index)/total_words)
                    new_row = {
                        'Text': line,
                        'Narrator': narrator,
                        'Language': language,
                        'Timecode Range': f'{start_time.time()} - {end_time.time()}',
                        'FilePath': row['filepath']
                    }
                matched_rows.append(new_row)
        else:  
            new_row = {
                'Text': line,
                'Narrator': narrator,
                'Language': language,
                'Timecode Range': None,
                'FilePath': None
            }
            matched_rows.append(new_row)

matched_df = pd.DataFrame(matched_rows)
matched_df.to_csv('../intermediate.csv', index=False)

# %%
import csv
import os
import xml.etree.ElementTree as ET
from datetime import datetime, timedelta
import copy
import random
import uuid


final_clip_list = []
id_mapping = {}
# global sequence_start
# global sequence_end

sequence_start=0
sequence_end=0
xml_file_assigned=[]

def create_xml(xml_name,xml_json_data):
    
    # Create the root element
    root = ET.Element("xmeml", version="4")
    
    # Create the sequence element with attributes
    sequence = ET.SubElement(root, "sequence", id="sequence-2", TL_SQAudioVisibleBase="0", TL_SQVideoVisibleBase="0",
                             TL_SQVisibleBaseTime="0", TL_SQAVDividerPosition="0.5", TL_SQHideShyTracks="0",
                             TL_SQHeaderWidth="236", TL_SQDataTrackViewControlState="0",
                             Monitor_ProgramZoomOut="340011984312000", Monitor_ProgramZoomIn="0",
                             TL_SQTimePerPixel="1.6034289012958367", MZ_EditLine="333083126376000",
                             MZ_Sequence_PreviewFrameSizeHeight="1080", MZ_Sequence_PreviewFrameSizeWidth="1920",
                             MZ_Sequence_AudioTimeDisplayFormat="200", MZ_Sequence_PreviewUseMaxRenderQuality="false",
                             MZ_Sequence_PreviewUseMaxBitDepth="false", MZ_Sequence_VideoTimeDisplayFormat="110",
                             MZ_WorkOutPoint="15235011792000", MZ_WorkInPoint="0", MZ_ZeroPoint="0", explodedTracks="true")
    
    # Add the uuid element
    uuid = ET.SubElement(sequence, "uuid")
    uuid.text = "50e61931-251f-4069-8193-a3fbad7f93ff"
    
    # Add the duration element
    duration = ET.SubElement(sequence, "duration")
    duration.text = "31533"
    
    # Add the rate element with nested timebase and ntsc elements
    rate = ET.SubElement(sequence, "rate")
    timebase = ET.SubElement(rate, "timebase")
    timebase.text = "24"
    ntsc = ET.SubElement(rate, "ntsc")
    ntsc.text = "TRUE"
    
    # Add the name element
    name_element = ET.SubElement(sequence, "name")
    name_element.text = xml_name
    
    # Add the media element with nested video and audio elements
    media = ET.SubElement(sequence, "media")
    video = ET.SubElement(media, "video")

    # Add the format element with nested samplecharacteristics element
    format_ = ET.SubElement(video, "format")
    samplecharacteristics = ET.SubElement(format_, "samplecharacteristics")
    
    # Add the rate element with nested timebase and ntsc elements inside samplecharacteristics
    rate = ET.SubElement(samplecharacteristics, "rate")
    timebase = ET.SubElement(rate, "timebase")
    timebase.text = "24"
    ntsc = ET.SubElement(rate, "ntsc")
    ntsc.text = "TRUE"
    
    # Add the codec element with nested name and appspecificdata elements
    codec = ET.SubElement(samplecharacteristics, "codec")
    name = ET.SubElement(codec, "name")
    name.text = "Apple ProRes 422"
    appspecificdata = ET.SubElement(codec, "appspecificdata")
    
    # Add the appname, appmanufacturer, and appversion elements inside appspecificdata
    appname = ET.SubElement(appspecificdata, "appname")
    appname.text = "Final Cut Pro"
    appmanufacturer = ET.SubElement(appspecificdata, "appmanufacturer")
    appmanufacturer.text = "Apple Inc."
    appversion = ET.SubElement(appspecificdata, "appversion")
    appversion.text = "7.0"
    
    # Add the data element with nested qtcodec element inside appspecificdata
    data = ET.SubElement(appspecificdata, "data")
    qtcodec = ET.SubElement(data, "qtcodec")
    codecname = ET.SubElement(qtcodec, "codecname")
    codecname.text = "Apple ProRes 422"
    codectypename = ET.SubElement(qtcodec, "codectypename")
    codectypename.text = "Apple ProRes 422"
    codectypecode = ET.SubElement(qtcodec, "codectypecode")
    codectypecode.text = "apcn"
    codecvendorcode = ET.SubElement(qtcodec, "codecvendorcode")
    codecvendorcode.text = "appl"
    spatialquality = ET.SubElement(qtcodec, "spatialquality")
    spatialquality.text = "1024"
    temporalquality = ET.SubElement(qtcodec, "temporalquality")
    temporalquality.text = "0"
    keyframerate = ET.SubElement(qtcodec, "keyframerate")
    keyframerate.text = "0"
    datarate = ET.SubElement(qtcodec, "datarate")
    datarate.text = "0"
    
    # Add the width, height, anamorphic, pixelaspectratio, fielddominance, and colordepth elements inside samplecharacteristics
    width = ET.SubElement(samplecharacteristics, "width")
    width.text = "1920"
    height = ET.SubElement(samplecharacteristics, "height")
    height.text = "1080"
    anamorphic = ET.SubElement(samplecharacteristics, "anamorphic")
    anamorphic.text = "FALSE"
    pixelaspectratio = ET.SubElement(samplecharacteristics, "pixelaspectratio")
    pixelaspectratio.text = "square"
    fielddominance = ET.SubElement(samplecharacteristics, "fielddominance")
    fielddominance.text = "none"
    colordepth = ET.SubElement(samplecharacteristics, "colordepth")
    colordepth.text = "24"

    # Get the track elements
    video_tracks = [1]
    audio_tracks = []
    for clip in xml_json_data:

        audio_track_indexes = [link["trackindex"] for link in clip["video_clips"][0]["links"] if link["mediatype"] == "audio"]
        # print(audio_track_indexes)
        for audio_track_index in audio_track_indexes:
            if audio_track_index not in audio_tracks:
                audio_tracks.append(audio_track_index)

    # Create video track elements and append video clips
    for video_track_index in video_tracks:
        video_track = ET.SubElement(video, "track", TL_SQTrackShy="0", TL_SQTrackExpandedHeight="25",
                                    TL_SQTrackExpanded="0", MZ_TrackTargeted="0")
        # video_track.set("trackindex", str(video_track_index))

        for clip in xml_json_data:
            video_clip = clip["video_clips"][0]["video_clip_element"]
            video_track.append(copy.deepcopy(video_clip))

   
    

    
    # Add the audio element inside media
    audio = ET.SubElement(media, "audio")

    # constant stuff

    # Create subelements and append them to the audio element
    num_output_channels = ET.SubElement(audio, 'numOutputChannels')
    num_output_channels.text = '2'

    format_element = ET.SubElement(audio, 'format')
    sample_characteristics = ET.SubElement(format_element, 'samplecharacteristics')
    depth = ET.SubElement(sample_characteristics, 'depth')
    depth.text = '16'
    sample_rate = ET.SubElement(sample_characteristics, 'samplerate')
    sample_rate.text = '48000'

    outputs = ET.SubElement(audio, 'outputs')

    group_1 = ET.SubElement(outputs, 'group')
    index_1 = ET.SubElement(group_1, 'index')
    index_1.text = '1'
    num_channels_1 = ET.SubElement(group_1, 'numchannels')
    num_channels_1.text = '1'
    downmix_1 = ET.SubElement(group_1, 'downmix')
    downmix_1.text = '0'
    channel_1 = ET.SubElement(group_1, 'channel')
    channel_index_1 = ET.SubElement(channel_1, 'index')
    channel_index_1.text = '1'

    group_2 = ET.SubElement(outputs, 'group')
    index_2 = ET.SubElement(group_2, 'index')
    index_2.text = '2'
    num_channels_2 = ET.SubElement(group_2, 'numchannels')
    num_channels_2.text = '1'
    downmix_2 = ET.SubElement(group_2, 'downmix')
    downmix_2.text = '0'
    channel_2 = ET.SubElement(group_2, 'channel')
    channel_index_2 = ET.SubElement(channel_2, 'index')
    channel_index_2.text = '2'

     # Create audio track elements and append audio clips
    for audio_track_index in audio_tracks:
        audio_track = ET.SubElement(audio, "track", TL_SQTrackAudioKeyframeStyle="0", TL_SQTrackShy="0",
                                    TL_SQTrackExpandedHeight="25", TL_SQTrackExpanded="0",
                                    MZ_TrackTargeted="1", PannerCurrentValue="0.5", PannerIsInverted="true",
                                    PannerStartKeyframe="-91445760000000000,0.5,0,0,0,0,0,0", PannerName="Balance",
                                    currentExplodedTrackIndex=f"{audio_track_index-1}", totalExplodedTrackCount="2",
                                    premiereTrackType="Stereo")
        # audio_track.set("trackindex", str(audio_track_index))

        for clip in xml_json_data:
            audio_clip_elements = clip["video_clips"][0]["linked_audio_clip_elements_list"]
            
            for audio_clip in audio_clip_elements:
                if audio_track_index == audio_clip[1]:
                    audio_track.append(copy.deepcopy(audio_clip[0]))
    
    # Add the timecode element with nested rate, string, frame, and displayformat elements
    timecode = ET.SubElement(sequence, "timecode")
    rate = ET.SubElement(timecode, "rate")
    timebase = ET.SubElement(rate, "timebase")
    timebase.text = "24"
    ntsc = ET.SubElement(rate, "ntsc")
    ntsc.text = "TRUE"
    string = ET.SubElement(timecode, "string")
    string.text = "00:00:00:00"
    frame = ET.SubElement(timecode, "frame")
    frame.text = "0"
    displayformat = ET.SubElement(timecode, "displayformat")
    displayformat.text = "NDF"
    
    # Add the labels element with nested label2 element
    labels = ET.SubElement(sequence, "labels")
    label2 = ET.SubElement(labels, "label2")
    label2.text = "Forest"
    


    
    # Create the ElementTree object with the root element
    tree = ET.ElementTree(root)
    
    # Generate a random Idd
    idd = str(random.randint(1, 1000))
    
    # Save the XML to a file
    filename = f"../xml exports/{xml_name.replace(' ', '_')}-{idd}.xml"
    tree.write(filename, encoding="utf-8", xml_declaration=True)
    print(f"XML saved to {filename}")


def generate_unique_id():
    unique_id = f"clipitem-{uuid.uuid4().hex}"
    return unique_id

def update_xml_ids(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    print('Assigning unique IDs to clipitem elements...')

    # Generate unique IDs for clipitem elements
      # Store the mapping of old IDs to new unique IDs
    for clip_item in root.findall('.//clipitem'):  # Adjust the XPath expression based on the actual location of clipitem elements
        current_id = clip_item.attrib['id']
        unique_id = generate_unique_id()
        id_mapping[current_id] = unique_id
        clip_item.attrib['id'] = unique_id

    
        # Update the references in the links section
    for link in root.findall('.//link'):
        linkclipref = link.find('linkclipref')
        if linkclipref is not None and linkclipref.text in id_mapping:
            linkclipref.text = id_mapping[linkclipref.text]
    print(id_mapping)

    # Save the modified XML file
    tree.write(xml_file, encoding="utf-8")



def extract_timecode(timecode_range):
    start_time, end_time = timecode_range.split(" - ")
    start_time = start_time.strip().replace(" ", "")
    end_time = end_time.strip().replace(" ", "")
    print('Start Time',start_time,'End Time', end_time)
    return start_time, end_time


def process_csv_file(csv_file, xml_folder):
    with open(csv_file, "r") as file:
        csv_reader = csv.DictReader(file)
        for row in csv_reader:
            timecode_range = row["Timecode Range"]
            if timecode_range:
                start_time, end_time = extract_timecode(timecode_range)
                narrator_name = row["Narrator"]
                # print('Narrator Name:' ,narrator_name)
                process_xml_files(xml_folder, start_time, end_time, narrator_name)


def process_xml_files(xml_folder, start_time, end_time, narrator_name):
    global xml_file_assigned,final_clip_list
    for filename in os.listdir(xml_folder):
        # print(filename,narrator_name,narrator_name.lower() in filename.lower())
        if filename.endswith(".xml") and narrator_name.lower() in filename.lower():
            # print(filename,narrator_name)
            xml_file = os.path.join(xml_folder, filename)
            if xml_file not in xml_file_assigned:
                update_xml_ids(xml_file)
                xml_file_assigned.append(xml_file)
            matched_clips = extract_sequence_info(xml_file, start_time, end_time)
            final_clip_list.append(matched_clips)



# def convert_time_to_frames(time, rate):
#     print('Time', time, 'Rate', rate)
#     time_format = "%H:%M:%S:%f"
#     time_obj = datetime.strptime(time, time_format)
#     milliseconds = time_obj.microsecond // 1000  # Convert microseconds to milliseconds
#     total_seconds = (time_obj.second + time_obj.minute * 60 + time_obj.hour * 3600)
#     total_seconds += milliseconds / 1000  # Add milliseconds
#     frame_count = int(total_seconds * rate)
#     return frame_count


def convert_time_to_frames(time, rate):
    # print('Time', time, 'Rate', rate)
    parts = time.split(":")
    hours = int(parts[0])
    minutes = int(parts[1])
    seconds = int(parts[2])
    frames = int(parts[3])
    
    # Calculate the total duration in frames
    total_frames = (
        hours * 3600 * rate +  # Convert hours to frames
        minutes * 60 * rate +  # Convert minutes to frames
        seconds * rate +  # Convert seconds to frames
        frames
    )
    
    return total_frames




def frame_to_ticks(frame_number, frame_rate):
    total_ticks_in_a_second = 254016000000
    tick_value = int((frame_number * total_ticks_in_a_second) / frame_rate)
    return tick_value


def extract_sequence_info(xml_file, start_time, end_time):
    global sequence_start, sequence_end
    tree = ET.parse(xml_file)
    root = tree.getroot()

    # Extract sequence information
    sequence = root.find('sequence')
    sequence_info = {
        'duration': int(sequence.find('duration').text),
        'rate': {
            'timebase': int(sequence.find('rate/timebase').text),
            'ntsc': sequence.find('rate/ntsc').text == 'TRUE'
        }
    }
    sequence_rate = sequence_info['rate']['timebase']

    # Convert start and end times to frames
    start_frame = convert_time_to_frames(start_time, sequence_rate)
    end_frame = convert_time_to_frames(end_time, sequence_rate)
    proTickIn=frame_to_ticks(start_frame,sequence_rate)
    proTickOut=frame_to_ticks(end_frame,sequence_rate)
    
    print('Start and End Frame',start_frame ,end_frame)
    print(sequence_rate,'sequence_rate')

    # Extract video clip information
    video_clips = []
    for clip_item in root.findall('.//video//clipitem'):  # Only consider clip items within the <video> tag
        
        clip_info = {
            'id': clip_item.attrib['id'],  # Get the clip ID
            'name': clip_item.find('name').text,
            'duration': int(clip_item.find('duration').text),
            'rate': {
                'timebase': int(clip_item.find('rate/timebase').text),
                'ntsc': clip_item.find('rate/ntsc').text == 'TRUE'
            },
            'in': int(clip_item.find('in').text),
            'out': int(clip_item.find('out').text),
            'start': int(clip_item.find('start').text),
            'end': int(clip_item.find('end').text),
            'links': [],  # Initialize an empty list to store links,
            'video_clip_element': None,  # Store the clip item element for later use
            'linked_audio_clip_elements_list': []  # Initialize an empty list to store linked clip items
        }

        if clip_info['in'] <= start_frame <= clip_info['out']:
            sequence_start=sequence_end+10
            sequence_end=sequence_start+(end_frame-start_frame)

        links = clip_item.findall('link')
        for link in links:
            link_info = {
                'linkclipref': link.find('linkclipref').text,
                'mediatype': link.find('mediatype').text,
                'trackindex': int(link.find('trackindex').text),
                'clipindex': int(link.find('clipindex').text)
            }
            if link.find('groupindex') is not None:
                link_info['groupindex'] = int(link.find('groupindex').text)
            clip_info['links'].append(link_info)
            if link.find('mediatype').text == 'audio':
                audio_clip_items = root.findall('.//audio//clipitem')
                for audio_clip_item in audio_clip_items:
                    if audio_clip_item.attrib['id'] == link.find('linkclipref').text:
                        audio_clip_item.find('in').text = str(start_frame)  
                        audio_clip_item.find('out').text = str(end_frame)
                        audio_clip_item.find('start').text = str(sequence_start)  
                        audio_clip_item.find('end').text = str(sequence_end)
                        audio_clip_item.find('pproTicksIn').text = str(proTickIn)  
                        audio_clip_item.find('pproTicksOut').text = str(proTickOut)
                        clip_info['linked_audio_clip_elements_list'].append([audio_clip_item,int(link.find('trackindex').text)])

        # Check if the clip's in or out frame falls within the given start and end frames
        print('Clip Frame Inside file Found: ',clip_info['in'] <= start_frame <= clip_info['out'])
        print('Start - Matching - End')
        print(clip_info['in'],start_frame,clip_info['out'])
        if clip_info['in'] <= start_frame <= clip_info['out']:
            clip_item.find('in').text = str(start_frame)  
            clip_item.find('out').text = str(end_frame)
            clip_item.find('start').text = str(sequence_start)  
            clip_item.find('end').text = str(sequence_end)
            clip_info['video_clip_element']=clip_item
            video_clips.append(clip_info)
            print('Next Sequence Start',sequence_start)
            print('Next Sequence End',sequence_end)
            
        
    # print(clip_info, start_frame, end_frame)

    # Create result dictionary
    result = {
        'sequence_info': sequence_info,
        'video_clips': video_clips
    }
    # print('Result',result)

    if not video_clips:  # Check if video_clips list is empty
        return None
    
    return result


# Example usage
csv_file = "../Script/script_export.csv"
xml_folder = "../Interview XML/"

process_csv_file(csv_file, xml_folder)
final_clip_list = [item for item in final_clip_list if item is not None]
print(final_clip_list)
create_xml('testy',final_clip_list)
# print(final_clip_list)
# Out:
# Start Time 00:13:33:00 End Time 00:13:45:09
# Assigning unique IDs to clipitem elements...
# {'clipitem-6c754d4ca1e546529bad5183503fd335': 'clipitem-3bc36d4d32de47a5ba6bb763bb7df09f', 'clipitem-4ec2d06d1c424369b94a405a3e3baafc': 'clipitem-39c4f3ec44064d0ab93e5753071d084c', 'clipitem-321764746a734bf59dde6ce4c4a4a217': 'clipitem-675810b439a34595bfbc47e904ee725b', 'clipitem-9540698b417248f08a9423b49db389fc': 'clipitem-69f7daef0e8f48af9b6d19704adc21e9', 'clipitem-2a843cf2dfc74696ac52e0e6863b2b6a': 'clipitem-e7fdc1e87fe44ab0841e322f1d67d00e', 'clipitem-83ab62c324a1408a86673376efae4659': 'clipitem-a54610b56d2149e1a4a8cd20a02d4235', 'clipitem-5d1d1596e57c4358975f27ffed69d17e': 'clipitem-79c5c967a26c48bd964cbc86747c02df', 'clipitem-e58cefbde1854713b343a46de811e72c': 'clipitem-401ccdd12f1b4ad4b6957718725326a4', 'clipitem-2879e622b5ba4018b3fa2bec4de26b19': 'clipitem-a072740ed7d7474fb21a99f42d5990d6', 'clipitem-afb87bf0aeca4b5ab2c2e1be1a210d55': 'clipitem-64bff2d976384ef2a78cca3854faa87b', 'clipitem-82475c2db6614a73ae59925d72fa97a6': 'clipitem-73196fc142824ce0a02a68d27caa69a6', 'clipitem-d66584c671674333acf85f1101d1d597': 'clipitem-5b2d6eece876491692ec0be9cd679631', 'clipitem-71155a946930438f8778a409ba6c59b4': 'clipitem-03e6d3a48d844323a2e9a4f011cc82dc', 'clipitem-dc479c37d3bb4dce9fcb07aa1fe7f1bb': 'clipitem-7f4f2082d9fc4f7e8981c9bace90cc25', 'clipitem-791e5e5a409b46229fb390c36413ae3e': 'clipitem-7d4a481187cf47d0b16b96a34a070561', 'clipitem-f2b27bdabdff4bc8b4b3960ed266010f': 'clipitem-b7d516ecba0a4051aff1247609996caf', 'clipitem-c7fc3da6e7774b9e8003af49a9f77171': 'clipitem-e6f0641c88a54ce1968fc2e767cb886c', 'clipitem-68ad702a1bd840058d2dd85700854fb6': 'clipitem-cfeeaed0bc2b487a8f6a03b23d6d3338', 'clipitem-3032f7ba36ac4baa84d46f4349db4cc7': 'clipitem-6c26f178d47e4433834448093cee4409', 'clipitem-bb116157458345b7ab6f8165ac5aad8d': 'clipitem-9452d26deec947769235669fe8f2dcf2', 'clipitem-bc1f79a0ce314603bd994bb5078b9540': 'clipitem-a6cb83105f0f4d6697235e9db1acc662', 'clipitem-e04d706f9c4b4a5cb5d529c7548484c3': 'clipitem-17ca3d7241ee4052b4627211ba52f7ca', 'clipitem-6b39ec145fe443228851a9875e1f0a84': 'clipitem-a794882a998e4e748ae20476c0e93787', 'clipitem-0301099f9bb64092b96cb44df300d053': 'clipitem-a4c29e802c9f4500920f1b972efc6480', 'clipitem-a4a23c02d3084c18b7eeac4e3d2d666c': 'clipitem-d6f74aa38c624302914c53d45ee1377d', 'clipitem-919a0d39bebf4c1a8bdfcc2b68e90e2a': 'clipitem-7ba1fea251d64af08345615524b40147', 'clipitem-3dd6797f9221472a86d36254fddf6aca': 'clipitem-97331270b39f4dbfb066c6c18bff04ef', 'clipitem-230388f677c14b9ea2f1bdd61d4a4279': 'clipitem-1d4929f4a2584c5db6f306ad8c0ac7e7', 'clipitem-4b8dd6ce6fec4ae38d2b8699a1b494a9': 'clipitem-54dfcef0431d4fc781953b3e1bc84a60', 'clipitem-6b57dec5f36e4e3389a9bdad96dee894': 'clipitem-79e8adb82bf5403392a73600ac2d51b1', 'clipitem-640821479dee464a8d273c1f775c5391': 'clipitem-5c116c396506457ca60b8ae2804bee13', 'clipitem-a3f8848d8f46490f8512ccbfa0a54901': 'clipitem-97277dadf2ab498c9065805fbbdc5532', 'clipitem-d8c2ce296e0a46ed87b3948f0eb705ce': 'clipitem-284a1a8e31a24590bff8379cbd23d332', 'clipitem-b108e249a3c8422ebde7917d987849ff': 'clipitem-576c2475d3c4437096aa2c11ca4aeec6', 'clipitem-bddf6dc1e73d483da013f0fe885b80d6': 'clipitem-05e3c639559747cb8548e7759eb7897a', 'clipitem-a4afea22a7894d339eb1c542805203b0': 'clipitem-4745441cd608409185847fd4ab320735', 'clipitem-f815ba8dba9e4a098e4cfdd66d1b0ce5': 'clipitem-fc90d46b12cb488b9767cc2a0829f684', 'clipitem-790feb09e8294d139258f4c028d63ec1': 'clipitem-e2b6bcfecee1467e92f01d5a897c3cad', 'clipitem-30cbf22944c448b78f8dbd8f57dabd21': 'clipitem-693113ff8c374df2ba1b9f4dcbb8d076', 'clipitem-98cdd01338e942ee836e87a518f478e2': 'clipitem-363a82b55b824d1690d7fe0698addaeb', 'clipitem-51716f07adbe4904bf9653a81d469094': 'clipitem-868fb9647c814967aae60435e3bc6daf', 'clipitem-f5c017bbcebc41cd9904406058752e1d': 'clipitem-ee6eeafae4584df1808468aaa14caf06', 'clipitem-c8d2c4a23be64f66988f9bfd4f71b47d': 'clipitem-779ca353e17543b8b8a5acad8dee6d5d', 'clipitem-5734f40a90cb49f584bcc19332d09395': 'clipitem-31ad7d1df9f74092ab186a6725f42689', 'clipitem-812a68efbfb84ab78e91c2b20ee89 ...
# Start and End Frame 19512 19809
# 24 sequence_rate
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 532 19512 42987
# Next Sequence Start 10
# Next Sequence End 307
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 177
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 133
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 798
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 324
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 622
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 407
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 200
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 78
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 29
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 148
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 187
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 551
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 700
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 360
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 2111
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 507
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 489
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 652
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 429
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 337
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 691
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 923
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 1044
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 1047
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 387
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 757
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 1154
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19512 1264
# Start Time 00:13:45:17 End Time 00:13:54:00
# Start and End Frame 19817 20016
# 24 sequence_rate
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 532 19817 42987
# Next Sequence Start 317
# Next Sequence End 516
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 177
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 133
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 798
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 324
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 622
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 407
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 200
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 78
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 29
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 148
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 187
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 551
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 700
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 360
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 2111
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 507
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 489
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 652
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 429
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 337
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 691
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 923
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 1044
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 1047
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 387
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 757
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 1154
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 19817 1264
# Start Time 00:14:04:00 End Time 00:14:20:00
# Start and End Frame 20256 20640
# 24 sequence_rate
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 532 20256 42987
# Next Sequence Start 526
# Next Sequence End 910
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 177
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 133
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 798
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 324
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 622
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 407
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 200
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 78
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 29
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 148
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 187
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 551
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 700
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 360
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 2111
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 507
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 489
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 652
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 429
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 337
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 691
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 923
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 1044
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 1047
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 387
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 757
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 1154
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 20256 1264
# Start Time 00:23:49:19 End Time 00:23:59:21
# Start and End Frame 34315 34557
# 24 sequence_rate
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 532 34315 42987
# Next Sequence Start 920
# Next Sequence End 1162
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 177
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 133
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 798
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 324
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 622
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 407
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 200
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 78
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 29
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 148
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 187
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 551
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 700
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 360
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 2111
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 507
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 489
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 652
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 429
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 337
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 691
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 923
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 1044
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 1047
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 387
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 757
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 1154
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 34315 1264
# Start Time 00:00:58:00 End Time 00:01:01:16
# Start and End Frame 1392 1480
# 24 sequence_rate
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 532 1392 42987
# Next Sequence Start 1172
# Next Sequence End 1260
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 177
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 133
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 798
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 324
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 622
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 407
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 200
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 78
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 29
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 148
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 187
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 551
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 700
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 360
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 0 1392 2111
# Next Sequence Start 1270
# Next Sequence End 1358
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 507
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 489
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 652
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 429
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 337
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 691
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 923
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 1044
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 1047
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 387
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 757
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 1154
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 1392 1264
# Start Time 00:03:56:00 End Time 00:04:00:00
# Start and End Frame 5664 5760
# 24 sequence_rate
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 532 5664 42987
# Next Sequence Start 1368
# Next Sequence End 1464
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 177
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 133
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 798
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 324
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 622
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 407
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 200
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 78
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 29
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 148
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 187
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 551
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 700
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 360
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 2111
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 507
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 489
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 652
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 429
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 337
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 691
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 923
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 1044
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 1047
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 387
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 757
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 1154
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 5664 1264
# Start Time 00:15:13:17 End Time 00:15:17:03
# Assigning unique IDs to clipitem elements...
# {'clipitem-6c754d4ca1e546529bad5183503fd335': 'clipitem-3bc36d4d32de47a5ba6bb763bb7df09f', 'clipitem-4ec2d06d1c424369b94a405a3e3baafc': 'clipitem-39c4f3ec44064d0ab93e5753071d084c', 'clipitem-321764746a734bf59dde6ce4c4a4a217': 'clipitem-675810b439a34595bfbc47e904ee725b', 'clipitem-9540698b417248f08a9423b49db389fc': 'clipitem-69f7daef0e8f48af9b6d19704adc21e9', 'clipitem-2a843cf2dfc74696ac52e0e6863b2b6a': 'clipitem-e7fdc1e87fe44ab0841e322f1d67d00e', 'clipitem-83ab62c324a1408a86673376efae4659': 'clipitem-a54610b56d2149e1a4a8cd20a02d4235', 'clipitem-5d1d1596e57c4358975f27ffed69d17e': 'clipitem-79c5c967a26c48bd964cbc86747c02df', 'clipitem-e58cefbde1854713b343a46de811e72c': 'clipitem-401ccdd12f1b4ad4b6957718725326a4', 'clipitem-2879e622b5ba4018b3fa2bec4de26b19': 'clipitem-a072740ed7d7474fb21a99f42d5990d6', 'clipitem-afb87bf0aeca4b5ab2c2e1be1a210d55': 'clipitem-64bff2d976384ef2a78cca3854faa87b', 'clipitem-82475c2db6614a73ae59925d72fa97a6': 'clipitem-73196fc142824ce0a02a68d27caa69a6', 'clipitem-d66584c671674333acf85f1101d1d597': 'clipitem-5b2d6eece876491692ec0be9cd679631', 'clipitem-71155a946930438f8778a409ba6c59b4': 'clipitem-03e6d3a48d844323a2e9a4f011cc82dc', 'clipitem-dc479c37d3bb4dce9fcb07aa1fe7f1bb': 'clipitem-7f4f2082d9fc4f7e8981c9bace90cc25', 'clipitem-791e5e5a409b46229fb390c36413ae3e': 'clipitem-7d4a481187cf47d0b16b96a34a070561', 'clipitem-f2b27bdabdff4bc8b4b3960ed266010f': 'clipitem-b7d516ecba0a4051aff1247609996caf', 'clipitem-c7fc3da6e7774b9e8003af49a9f77171': 'clipitem-e6f0641c88a54ce1968fc2e767cb886c', 'clipitem-68ad702a1bd840058d2dd85700854fb6': 'clipitem-cfeeaed0bc2b487a8f6a03b23d6d3338', 'clipitem-3032f7ba36ac4baa84d46f4349db4cc7': 'clipitem-6c26f178d47e4433834448093cee4409', 'clipitem-bb116157458345b7ab6f8165ac5aad8d': 'clipitem-9452d26deec947769235669fe8f2dcf2', 'clipitem-bc1f79a0ce314603bd994bb5078b9540': 'clipitem-a6cb83105f0f4d6697235e9db1acc662', 'clipitem-e04d706f9c4b4a5cb5d529c7548484c3': 'clipitem-17ca3d7241ee4052b4627211ba52f7ca', 'clipitem-6b39ec145fe443228851a9875e1f0a84': 'clipitem-a794882a998e4e748ae20476c0e93787', 'clipitem-0301099f9bb64092b96cb44df300d053': 'clipitem-a4c29e802c9f4500920f1b972efc6480', 'clipitem-a4a23c02d3084c18b7eeac4e3d2d666c': 'clipitem-d6f74aa38c624302914c53d45ee1377d', 'clipitem-919a0d39bebf4c1a8bdfcc2b68e90e2a': 'clipitem-7ba1fea251d64af08345615524b40147', 'clipitem-3dd6797f9221472a86d36254fddf6aca': 'clipitem-97331270b39f4dbfb066c6c18bff04ef', 'clipitem-230388f677c14b9ea2f1bdd61d4a4279': 'clipitem-1d4929f4a2584c5db6f306ad8c0ac7e7', 'clipitem-4b8dd6ce6fec4ae38d2b8699a1b494a9': 'clipitem-54dfcef0431d4fc781953b3e1bc84a60', 'clipitem-6b57dec5f36e4e3389a9bdad96dee894': 'clipitem-79e8adb82bf5403392a73600ac2d51b1', 'clipitem-640821479dee464a8d273c1f775c5391': 'clipitem-5c116c396506457ca60b8ae2804bee13', 'clipitem-a3f8848d8f46490f8512ccbfa0a54901': 'clipitem-97277dadf2ab498c9065805fbbdc5532', 'clipitem-d8c2ce296e0a46ed87b3948f0eb705ce': 'clipitem-284a1a8e31a24590bff8379cbd23d332', 'clipitem-b108e249a3c8422ebde7917d987849ff': 'clipitem-576c2475d3c4437096aa2c11ca4aeec6', 'clipitem-bddf6dc1e73d483da013f0fe885b80d6': 'clipitem-05e3c639559747cb8548e7759eb7897a', 'clipitem-a4afea22a7894d339eb1c542805203b0': 'clipitem-4745441cd608409185847fd4ab320735', 'clipitem-f815ba8dba9e4a098e4cfdd66d1b0ce5': 'clipitem-fc90d46b12cb488b9767cc2a0829f684', 'clipitem-790feb09e8294d139258f4c028d63ec1': 'clipitem-e2b6bcfecee1467e92f01d5a897c3cad', 'clipitem-30cbf22944c448b78f8dbd8f57dabd21': 'clipitem-693113ff8c374df2ba1b9f4dcbb8d076', 'clipitem-98cdd01338e942ee836e87a518f478e2': 'clipitem-363a82b55b824d1690d7fe0698addaeb', 'clipitem-51716f07adbe4904bf9653a81d469094': 'clipitem-868fb9647c814967aae60435e3bc6daf', 'clipitem-f5c017bbcebc41cd9904406058752e1d': 'clipitem-ee6eeafae4584df1808468aaa14caf06', 'clipitem-c8d2c4a23be64f66988f9bfd4f71b47d': 'clipitem-779ca353e17543b8b8a5acad8dee6d5d', 'clipitem-5734f40a90cb49f584bcc19332d09395': 'clipitem-31ad7d1df9f74092ab186a6725f42689', 'clipitem-812a68efbfb84ab78e91c2b20ee89 ...
# Start and End Frame 21929 22011
# 24 sequence_rate
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 4179 21929 52602
# Next Sequence Start 1474
# Next Sequence End 1556
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 0 21929 39100
# Next Sequence Start 1566
# Next Sequence End 1648
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 2049
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 3573
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 4366
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 298
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 609
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 434
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 128
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 577
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 1654
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 483
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 298
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 294
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 180
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 236
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 1132
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 1461
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 555
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 107
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 160
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 378
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 1783
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 937
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 562
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 552
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 94
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 1657
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 334
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 2014
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 1280
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 177
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 1057
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 1089
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 487
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 1456
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 593
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 539
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 21929 555
# Start Time 00:15:47:06 End Time 00:15:49:04
# Start and End Frame 22734 22780
# 24 sequence_rate
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 4179 22734 52602
# Next Sequence Start 1658
# Next Sequence End 1704
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 0 22734 39100
# Next Sequence Start 1714
# Next Sequence End 1760
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 2049
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 3573
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 4366
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 298
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 609
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 434
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 128
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 577
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 1654
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 483
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 298
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 294
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 180
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 236
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 1132
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 1461
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 555
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 107
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 160
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 378
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 1783
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 937
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 562
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 552
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 94
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 1657
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 334
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 2014
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 1280
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 177
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 1057
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 1089
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 487
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 1456
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 593
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 539
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22734 555
# Start Time 00:15:49:05 End Time 00:15:52:00
# Start and End Frame 22781 22848
# 24 sequence_rate
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 4179 22781 52602
# Next Sequence Start 1770
# Next Sequence End 1837
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 0 22781 39100
# Next Sequence Start 1847
# Next Sequence End 1914
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 2049
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 3573
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 4366
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 298
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 609
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 434
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 128
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 577
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 1654
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 483
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 298
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 294
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 180
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 236
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 1132
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 1461
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 555
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 107
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 160
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 378
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 1783
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 937
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 562
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 552
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 94
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 1657
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 334
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 2014
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 1280
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 177
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 1057
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 1089
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 487
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 1456
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 593
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 539
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22781 555
# Start Time 00:15:52:00 End Time 00:15:53:09
# Start and End Frame 22848 22881
# 24 sequence_rate
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 4179 22848 52602
# Next Sequence Start 1924
# Next Sequence End 1957
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 0 22848 39100
# Next Sequence Start 1967
# Next Sequence End 2000
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 2049
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 3573
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 4366
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 298
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 609
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 434
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 128
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 577
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 1654
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 483
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 298
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 294
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 180
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 236
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 1132
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 1461
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 555
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 107
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 160
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 378
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 1783
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 937
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 562
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 552
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 94
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 1657
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 334
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 2014
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 1280
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 177
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 1057
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 1089
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 487
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 1456
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 593
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 539
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22848 555
# Start Time 00:15:53:10 End Time 00:15:55:09
# Start and End Frame 22882 22929
# 24 sequence_rate
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 4179 22882 52602
# Next Sequence Start 2010
# Next Sequence End 2057
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 0 22882 39100
# Next Sequence Start 2067
# Next Sequence End 2114
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 2049
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 3573
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 4366
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 298
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 609
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 434
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 128
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 577
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 1654
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 483
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 298
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 294
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 180
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 236
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 1132
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 1461
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 555
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 107
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 160
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 378
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 1783
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 937
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 562
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 552
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 94
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 1657
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 334
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 2014
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 1280
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 177
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 1057
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 1089
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 487
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 1456
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 593
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 539
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 22882 555
# Start Time 00:21:17:22 End Time 00:21:20:12
# Assigning unique IDs to clipitem elements...
# {'clipitem-6c754d4ca1e546529bad5183503fd335': 'clipitem-3bc36d4d32de47a5ba6bb763bb7df09f', 'clipitem-4ec2d06d1c424369b94a405a3e3baafc': 'clipitem-39c4f3ec44064d0ab93e5753071d084c', 'clipitem-321764746a734bf59dde6ce4c4a4a217': 'clipitem-675810b439a34595bfbc47e904ee725b', 'clipitem-9540698b417248f08a9423b49db389fc': 'clipitem-69f7daef0e8f48af9b6d19704adc21e9', 'clipitem-2a843cf2dfc74696ac52e0e6863b2b6a': 'clipitem-e7fdc1e87fe44ab0841e322f1d67d00e', 'clipitem-83ab62c324a1408a86673376efae4659': 'clipitem-a54610b56d2149e1a4a8cd20a02d4235', 'clipitem-5d1d1596e57c4358975f27ffed69d17e': 'clipitem-79c5c967a26c48bd964cbc86747c02df', 'clipitem-e58cefbde1854713b343a46de811e72c': 'clipitem-401ccdd12f1b4ad4b6957718725326a4', 'clipitem-2879e622b5ba4018b3fa2bec4de26b19': 'clipitem-a072740ed7d7474fb21a99f42d5990d6', 'clipitem-afb87bf0aeca4b5ab2c2e1be1a210d55': 'clipitem-64bff2d976384ef2a78cca3854faa87b', 'clipitem-82475c2db6614a73ae59925d72fa97a6': 'clipitem-73196fc142824ce0a02a68d27caa69a6', 'clipitem-d66584c671674333acf85f1101d1d597': 'clipitem-5b2d6eece876491692ec0be9cd679631', 'clipitem-71155a946930438f8778a409ba6c59b4': 'clipitem-03e6d3a48d844323a2e9a4f011cc82dc', 'clipitem-dc479c37d3bb4dce9fcb07aa1fe7f1bb': 'clipitem-7f4f2082d9fc4f7e8981c9bace90cc25', 'clipitem-791e5e5a409b46229fb390c36413ae3e': 'clipitem-7d4a481187cf47d0b16b96a34a070561', 'clipitem-f2b27bdabdff4bc8b4b3960ed266010f': 'clipitem-b7d516ecba0a4051aff1247609996caf', 'clipitem-c7fc3da6e7774b9e8003af49a9f77171': 'clipitem-e6f0641c88a54ce1968fc2e767cb886c', 'clipitem-68ad702a1bd840058d2dd85700854fb6': 'clipitem-cfeeaed0bc2b487a8f6a03b23d6d3338', 'clipitem-3032f7ba36ac4baa84d46f4349db4cc7': 'clipitem-6c26f178d47e4433834448093cee4409', 'clipitem-bb116157458345b7ab6f8165ac5aad8d': 'clipitem-9452d26deec947769235669fe8f2dcf2', 'clipitem-bc1f79a0ce314603bd994bb5078b9540': 'clipitem-a6cb83105f0f4d6697235e9db1acc662', 'clipitem-e04d706f9c4b4a5cb5d529c7548484c3': 'clipitem-17ca3d7241ee4052b4627211ba52f7ca', 'clipitem-6b39ec145fe443228851a9875e1f0a84': 'clipitem-a794882a998e4e748ae20476c0e93787', 'clipitem-0301099f9bb64092b96cb44df300d053': 'clipitem-a4c29e802c9f4500920f1b972efc6480', 'clipitem-a4a23c02d3084c18b7eeac4e3d2d666c': 'clipitem-d6f74aa38c624302914c53d45ee1377d', 'clipitem-919a0d39bebf4c1a8bdfcc2b68e90e2a': 'clipitem-7ba1fea251d64af08345615524b40147', 'clipitem-3dd6797f9221472a86d36254fddf6aca': 'clipitem-97331270b39f4dbfb066c6c18bff04ef', 'clipitem-230388f677c14b9ea2f1bdd61d4a4279': 'clipitem-1d4929f4a2584c5db6f306ad8c0ac7e7', 'clipitem-4b8dd6ce6fec4ae38d2b8699a1b494a9': 'clipitem-54dfcef0431d4fc781953b3e1bc84a60', 'clipitem-6b57dec5f36e4e3389a9bdad96dee894': 'clipitem-79e8adb82bf5403392a73600ac2d51b1', 'clipitem-640821479dee464a8d273c1f775c5391': 'clipitem-5c116c396506457ca60b8ae2804bee13', 'clipitem-a3f8848d8f46490f8512ccbfa0a54901': 'clipitem-97277dadf2ab498c9065805fbbdc5532', 'clipitem-d8c2ce296e0a46ed87b3948f0eb705ce': 'clipitem-284a1a8e31a24590bff8379cbd23d332', 'clipitem-b108e249a3c8422ebde7917d987849ff': 'clipitem-576c2475d3c4437096aa2c11ca4aeec6', 'clipitem-bddf6dc1e73d483da013f0fe885b80d6': 'clipitem-05e3c639559747cb8548e7759eb7897a', 'clipitem-a4afea22a7894d339eb1c542805203b0': 'clipitem-4745441cd608409185847fd4ab320735', 'clipitem-f815ba8dba9e4a098e4cfdd66d1b0ce5': 'clipitem-fc90d46b12cb488b9767cc2a0829f684', 'clipitem-790feb09e8294d139258f4c028d63ec1': 'clipitem-e2b6bcfecee1467e92f01d5a897c3cad', 'clipitem-30cbf22944c448b78f8dbd8f57dabd21': 'clipitem-693113ff8c374df2ba1b9f4dcbb8d076', 'clipitem-98cdd01338e942ee836e87a518f478e2': 'clipitem-363a82b55b824d1690d7fe0698addaeb', 'clipitem-51716f07adbe4904bf9653a81d469094': 'clipitem-868fb9647c814967aae60435e3bc6daf', 'clipitem-f5c017bbcebc41cd9904406058752e1d': 'clipitem-ee6eeafae4584df1808468aaa14caf06', 'clipitem-c8d2c4a23be64f66988f9bfd4f71b47d': 'clipitem-779ca353e17543b8b8a5acad8dee6d5d', 'clipitem-5734f40a90cb49f584bcc19332d09395': 'clipitem-31ad7d1df9f74092ab186a6725f42689', 'clipitem-812a68efbfb84ab78e91c2b20ee89 ...
# Start and End Frame 30670 30732
# 24 sequence_rate
# Clip Frame Inside file Found:  True
# Start - Matching - End
# 1671 30670 33204
# Next Sequence Start 2124
# Next Sequence End 2186
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 31 30670 174
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 104
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 196
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 85
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 185
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 105
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 259
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 187
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 149
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 293
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 244
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 313
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 195
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 259
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 360
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 56
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 437
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 268
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 340
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 172
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 168
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 189
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 563
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 212
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 206
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 244
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 448
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 285
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 200
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 192
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 436
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 874
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 142
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 308
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 370
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 391
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 160
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 75
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 300
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 441
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 97
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 529
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 488
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 202
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 179
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 304
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 478
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 30670 59
# Assigning unique IDs to clipitem elements...
# ...
# 0 65531 391
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65531 160
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65531 75
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65531 300
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65531 441
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65531 97
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65531 529
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65531 488
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65531 202
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65531 179
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65531 304
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65531 478
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65531 59
# Start and End Frame 81911 82012
# 30 sequence_rate
# Start Time 00:45:28:00 End Time 00:45:29:20
# Start and End Frame 65472 65516
# 24 sequence_rate
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 1671 65472 33204
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 31 65472 174
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 104
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 196
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 85
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 185
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 105
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 259
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 187
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 149
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 293
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 244
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 313
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 195
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 259
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 360
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 56
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 437
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 268
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 340
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 172
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 168
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 189
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 563
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 212
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 206
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 244
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 448
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 285
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 200
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 192
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 436
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 874
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 142
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 308
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 370
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 391
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 160
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 75
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 300
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 441
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 97
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 529
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 488
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 202
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 179
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 304
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 478
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65472 59
# Start and End Frame 81840 81890
# 30 sequence_rate
# Start Time 00:45:29:22 End Time 00:45:33:22
# Start and End Frame 65518 65614
# 24 sequence_rate
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 1671 65518 33204
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 31 65518 174
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 104
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 196
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 85
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 185
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 105
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 259
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 187
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 149
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 293
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 244
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 313
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 195
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 259
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 360
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 56
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 437
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 268
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 340
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 172
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 168
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 189
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 563
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 212
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 206
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 244
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 448
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 285
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 200
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 192
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 436
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 874
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 142
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 308
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 370
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 391
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 160
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 75
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 300
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 441
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 97
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 529
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 488
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 202
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 179
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 304
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 478
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65518 59
# Start and End Frame 81892 82012
# 30 sequence_rate
# Start Time 00:45:34:01 End Time 00:45:36:00
# Start and End Frame 65617 65664
# 24 sequence_rate
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 1671 65617 33204
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 31 65617 174
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 104
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 196
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 85
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 185
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 105
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 259
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 187
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 149
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 293
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 244
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 313
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 195
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 259
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 360
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 56
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 437
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 268
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 340
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 172
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 168
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 189
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 563
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 212
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 206
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 244
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 448
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 285
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 200
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 192
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 436
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 874
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 142
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 308
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 370
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 391
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 160
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 75
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 300
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 441
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 97
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 529
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 488
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 202
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 179
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 304
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 478
# Clip Frame Inside file Found:  False
# Start - Matching - End
# 0 65617 59
# Start and End Frame 82021 82080
# 30 sequence_rate
# [{'sequence_info': {'duration': 42455, 'rate': {'timebase': 24, 'ntsc': True}}, 'video_clips': [{'id': 'clipitem-3bc36d4d32de47a5ba6bb763bb7df09f', 'name': 'wiblo_1_2002-11-01_1409_C0010.mov', 'duration': 42987, 'rate': {'timebase': 24, 'ntsc': True}, 'in': 532, 'out': 42987, 'start': 0, 'end': 42455, 'links': [{'linkclipref': 'clipitem-3bc36d4d32de47a5ba6bb763bb7df09f', 'mediatype': 'video', 'trackindex': 1, 'clipindex': 1}, {'linkclipref': 'clipitem-79e8adb82bf5403392a73600ac2d51b1', 'mediatype': 'audio', 'trackindex': 1, 'clipindex': 1, 'groupindex': 1}, {'linkclipref': 'clipitem-5c116c396506457ca60b8ae2804bee13', 'mediatype': 'audio', 'trackindex': 2, 'clipindex': 1, 'groupindex': 1}], 'video_clip_element': <Element 'clipitem' at 0x000001EC67605710>, 'linked_audio_clip_elements_list': [[<Element 'clipitem' at 0x000001EC68D39440>, 1], [<Element 'clipitem' at 0x000001EC68D3B6F0>, 2]]}]}, {'sequence_info': {'duration': 42455, 'rate': {'timebase': 24, 'ntsc': True}}, 'video_clips': [{'id': 'clipitem-3bc36d4d32de47a5ba6bb763bb7df09f', 'name': 'wiblo_1_2002-11-01_1409_C0010.mov', 'duration': 42987, 'rate': {'timebase': 24, 'ntsc': True}, 'in': 532, 'out': 42987, 'start': 0, 'end': 42455, 'links': [{'linkclipref': 'clipitem-3bc36d4d32de47a5ba6bb763bb7df09f', 'mediatype': 'video', 'trackindex': 1, 'clipindex': 1}, {'linkclipref': 'clipitem-79e8adb82bf5403392a73600ac2d51b1', 'mediatype': 'audio', 'trackindex': 1, 'clipindex': 1, 'groupindex': 1}, {'linkclipref': 'clipitem-5c116c396506457ca60b8ae2804bee13', 'mediatype': 'audio', 'trackindex': 2, 'clipindex': 1, 'groupindex': 1}], 'video_clip_element': <Element 'clipitem' at 0x000001EC67543380>, 'linked_audio_clip_elements_list': [[<Element 'clipitem' at 0x000001EC692BD4E0>, 1], [<Element 'clipitem' at 0x000001EC692BD8A0>, 2]]}]}, {'sequence_info': {'duration': 42455, 'rate': {'timebase': 24, 'ntsc': True}}, 'video_clips': [{'id': 'clipitem-3bc36d4d32de47a5ba6bb763bb7df09f', 'name': 'wiblo_1_2002-11-01_1409_C0010.mov', 'duration': 42987, 'rate': {'timebase': 24, 'ntsc': True}, 'in': 532, 'out': 42987, 'start': 0, 'end': 42455, 'links': [{'linkclipref': 'clipitem-3bc36d4d32de47a5ba6bb763bb7df09f', 'mediatype': 'video', 'trackindex': 1, 'clipindex': 1}, {'linkclipref': 'clipitem-79e8adb82bf5403392a73600ac2d51b1', 'mediatype': 'audio', 'trackindex': 1, 'clipindex': 1, 'groupindex': 1}, {'linkclipref': 'clipitem-5c116c396506457ca60b8ae2804bee13', 'mediatype': 'audio', 'trackindex': 2, 'clipindex': 1, 'groupindex': 1}], 'video_clip_element': <Element 'clipitem' at 0x000001EC68736A20>, 'linked_audio_clip_elements_list': [[<Element 'clipitem' at 0x000001EC694D56C0>, 1], [<Element 'clipitem' at 0x000001EC694D4680>, 2]]}]}, {'sequence_info': {'duration': 42455, 'rate': {'timebase': 24, 'ntsc': True}}, 'video_clips': [{'id': 'clipitem-3bc36d4d32de47a5ba6bb763bb7df09f', 'name': 'wiblo_1_2002-11-01_1409_C0010.mov', 'duration': 42987, 'rate': {'timebase': 24, 'ntsc': True}, 'in': 532, 'out': 42987, 'start': 0, 'end': 42455, 'links': [{'linkclipref': 'clipitem-3bc36d4d32de47a5ba6bb763bb7df09f', 'mediatype': 'video', 'trackindex': 1, 'clipindex': 1}, {'linkclipref': 'clipitem-79e8adb82bf5403392a73600ac2d51b1', 'mediatype': 'audio', 'trackindex': 1, 'clipindex': 1, 'groupindex': 1}, {'linkclipref': 'clipitem-5c116c396506457ca60b8ae2804bee13', 'mediatype': 'audio', 'trackindex': 2, 'clipindex': 1, 'groupindex': 1}], 'video_clip_element': <Element 'clipitem' at 0x000001EC690FF290>, 'linked_audio_clip_elements_list': [[<Element 'clipitem' at 0x000001EC675AD2B0>, 1], [<Element 'clipitem' at 0x000001EC675AFAB0>, 2]]}]}, {'sequence_info': {'duration': 42455, 'rate': {'timebase': 24, 'ntsc': True}}, 'video_clips': [{'id': 'clipitem-3bc36d4d32de47a5ba6bb763bb7df09f', 'name': 'wiblo_1_2002-11-01_1409_C0010.mov', 'duration': 42987, 'rate': {'timebase': 24, 'ntsc': True}, 'in': 532, 'out': 42987, 'start': 0, 'end': 42455, 'links': [{'linkclipref': 'clipitem-3bc36d4d32de47a5ba6bb763bb7df09f', 'mediatype': 'vide ...
# XML saved to ../xml exports/testy-972.xml
