# %%
import xml.etree.ElementTree as ET

# Create the root element
root = ET.Element('xmeml', version='4')

# Create the sequence element
sequence = ET.SubElement(root, 'sequence', MZ_EditLine="534253087368000",
                         MZ_Sequence_AudioTimeDisplayFormat="200",
                         MZ_Sequence_EditingModeGUID="35d109db-457b-43c1-9452-9cb7be9f121c",
                         MZ_Sequence_PreviewFrameSizeHeight="1080",
                         MZ_Sequence_PreviewFrameSizeWidth="1920",
                         MZ_Sequence_PreviewRenderingClassID="1297106761",
                         MZ_Sequence_PreviewRenderingPresetCodec="1297107278",
                         MZ_Sequence_PreviewRenderingPresetPath="EncoderPresets/SequencePreview/35d109db-457b-43c1-9452-9cb7be9f121c/I-Frame Only MPEG.epr",
                         MZ_Sequence_PreviewUseMaxBitDepth="false",
                         MZ_Sequence_PreviewUseMaxRenderQuality="false",
                         MZ_Sequence_VideoTimeDisplayFormat="110",
                         MZ_WorkInPoint="0",
                         MZ_WorkOutPoint="15235011792000",
                         Monitor_ProgramZoomIn="256929256584000",
                         Monitor_ProgramZoomOut="528807471192000",
                         TL_SQAVDividerPosition="0.5",
                         TL_SQAudioVisibleBase="0",
                         TL_SQHeaderWidth="236",
                         TL_SQHideShyTracks="0",
                         TL_SQTimePerPixel="2.7993612125956853",
                         TL_SQVideoVisibleBase="0",
                         TL_SQVisibleBaseTime="0",
                         explodedTracks="true",
                         id="sequence-18")

# Create the rate element
rate = ET.SubElement(sequence, 'rate')
timebase = ET.SubElement(rate, 'timebase')
timebase.text = '24'
ntsc = ET.SubElement(rate, 'ntsc')
ntsc.text = 'TRUE'

# Create the name element
name = ET.SubElement(sequence, 'name')
name.text = 'ross - synced'

# Create the duration element
duration = ET.SubElement(sequence, 'duration')
duration.text = '49830'

# Create the media element
media = ET.SubElement(sequence, 'media')

# Create the video element
video = ET.SubElement(media, 'video')

# Create the format element
format_ = ET.SubElement(video, 'format')

# Create the samplecharacteristics element
samplecharacteristics = ET.SubElement(format_, 'samplecharacteristics')

# Create the rate element for video sample characteristics
rate = ET.SubElement(samplecharacteristics, 'rate')
timebase = ET.SubElement(rate, 'timebase')
timebase.text = '24'
ntsc = ET.SubElement(rate, 'ntsc')
ntsc.text = 'TRUE'

# Create the codec element
codec = ET.SubElement(samplecharacteristics, 'codec')
name = ET.SubElement(codec, 'name')
name.text = 'Apple ProRes 422'
appspecificdata = ET.SubElement(codec, 'appspecificdata')
appname = ET.SubElement(appspecificdata, 'appname')
appname.text = 'Final Cut Pro'
appmanufacturer = ET.SubElement(appspecificdata, 'appmanufacturer')
appmanufacturer.text = 'Apple Inc.'
appversion = ET.SubElement(appspecificdata, 'appversion')
appversion.text = '7.0'
data = ET.SubElement(appspecificdata, 'data')
qtcodec = ET.SubElement(data, 'qtcodec')
codecname = ET.SubElement(qtcodec, 'codecname')
codecname.text = 'Apple ProRes 422'
codectypename = ET.SubElement(qtcodec, 'codectypename')
codectypename.text = 'Apple ProRes 422'
codectypecode = ET.SubElement(qtcodec, 'codectypecode')
codectypecode.text = 'apcn'
codecvendorcode = ET.SubElement(qtcodec, 'codecvendorcode')
codecvendorcode.text = 'appl'
spatialquality = ET.SubElement(qtcodec, 'spatialquality')
spatialquality.text = '1024'
temporalquality = ET.SubElement(qtcodec, 'temporalquality')
temporalquality.text = '0'
keyframerate = ET.SubElement(qtcodec, 'keyframerate')
keyframerate.text = '0'
datarate = ET.SubElement(qtcodec, 'datarate')
datarate.text = '0'

# Create the width and height elements
width = ET.SubElement(samplecharacteristics, 'width')
width.text = '1920'
height = ET.SubElement(samplecharacteristics, 'height')
height.text = '1080'

# Create the anamorphic, pixelaspectratio, and fielddominance elements
anamorphic = ET.SubElement(samplecharacteristics, 'anamorphic')
anamorphic.text = 'FALSE'
pixelaspectratio = ET.SubElement(samplecharacteristics, 'pixelaspectratio')
pixelaspectratio.text = 'square'
fielddominance = ET.SubElement(samplecharacteristics, 'fielddominance')
fielddominance.text = 'none'

# Create the track element
track = ET.SubElement(video, 'track')

# Create the clipitem element
clipitem = ET.SubElement(track, 'clipitem', id='clipitem-S3-V1-1')

# Create the name element for clipitem
name = ET.SubElement(clipitem, 'name')
name.text = 'wiblo_1_2002-09-23_2048_C0001.mov'

# Create the enabled element for clipitem
enabled = ET.SubElement(clipitem, 'enabled')
enabled.text = 'TRUE'

# Create the duration element for clipitem
duration = ET.SubElement(clipitem, 'duration')
duration.text = '38602'

# Create the rate element for clipitem
rate = ET.SubElement(clipitem, 'rate')
timebase = ET.SubElement(rate, 'timebase')
timebase.text = '24'
ntsc = ET.SubElement(rate, 'ntsc')
ntsc.text = 'TRUE'

# Create the start, end, in, and out elements for clipitem
start = ET.SubElement(clipitem, 'start')
start.text = '10943'
end = ET.SubElement(clipitem, 'end')
end.text = '49545'
in_ = ET.SubElement(clipitem, 'in')
in_.text = '0'
out = ET.SubElement(clipitem, 'out')
out.text = '38602'

# Create the file element for clipitem
file = ET.SubElement(clipitem, 'file', id='file-403')

# Create the name element for file
name = ET.SubElement(file, 'name')
name.text = 'wiblo_1_2002-09-23_2048_C0001.mov'

# Create the pathurl element
pathurl = ET.SubElement(file, 'pathurl')
pathurl.text = '/Volumes/tiesta/01_Footage/blantyre/wiblo_1_2002-09-23_2048_C0001.mov'

# Create the rate element for file
rate = ET.SubElement(file, 'rate')
timebase = ET.SubElement(rate, 'timebase')
timebase.text = '24'
ntsc = ET.SubElement(rate, 'ntsc')
ntsc.text = 'TRUE'

# Create the duration element for file
duration = ET.SubElement(file, 'duration')
duration.text = '38602'

# Create the timecode element for file
timecode = ET.SubElement(file, 'timecode')
timecode_string = ET.SubElement(timecode, 'string')
timecode_string.text = '20:48:23:00'
displayformat = ET.SubElement(timecode, 'displayformat')
displayformat.text = 'NDF'
frame = ET.SubElement(timecode, 'frame')
frame.text = '1797672'
rate = ET.SubElement(timecode, 'rate')
timebase = ET.SubElement(rate, 'timebase')
timebase.text = '24'
ntsc = ET.SubElement(rate, 'ntsc')
ntsc.text = 'TRUE'

# Create the media element for file
media = ET.SubElement(file, 'media')

# Create the video element for media
video = ET.SubElement(media, 'video')

# Create the samplecharacteristics element for video
samplecharacteristics = ET.SubElement(video, 'samplecharacteristics')

# Create the rate element for video sample characteristics
rate = ET.SubElement(samplecharacteristics, 'rate')
timebase = ET.SubElement(rate, 'timebase')
timebase.text = '24'
ntsc = ET.SubElement(rate, 'ntsc')
ntsc.text = 'TRUE'

# Create the width and height elements for video sample characteristics
width = ET.SubElement(samplecharacteristics, 'width')
width.text = '1920'
height = ET.SubElement(samplecharacteristics, 'height')
height.text = '1080'

# Create the anamorphic, pixelaspectratio, and fielddominance elements for video sample characteristics
anamorphic = ET.SubElement(samplecharacteristics, 'anamorphic')
anamorphic.text = 'FALSE'
pixelaspectratio = ET.SubElement(samplecharacteristics, 'pixelaspectratio')
pixelaspectratio.text = 'square'
fielddominance = ET.SubElement(samplecharacteristics, 'fielddominance')
fielddominance.text = 'none'

# Create the audio element for media
audio = ET.SubElement(media, 'audio')

# Create the samplecharacteristics element for audio
samplecharacteristics = ET.SubElement(audio, 'samplecharacteristics')

# Create the depth and samplerate elements for audio sample characteristics
depth = ET.SubElement(samplecharacteristics, 'depth')
depth.text = '16'
samplerate = ET.SubElement(samplecharacteristics, 'samplerate')
samplerate.text = '48000'

# Create the channelcount element for audio sample characteristics
channelcount = ET.SubElement(audio, 'channelcount')
channelcount.text = '2'

# Create the enabled and locked elements for track
enabled = ET.SubElement(track, 'enabled')
enabled.text = 'TRUE'
locked = ET.SubElement(track, 'locked')
locked.text = 'FALSE'

tree = ET.ElementTree(root)

# Write the XML tree to a file
with open('output.xml', 'w', encoding='utf-8') as file:
    file.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    file.write('<!DOCTYPE xmeml>\n')
    tree.write(file, encoding='unicode')
